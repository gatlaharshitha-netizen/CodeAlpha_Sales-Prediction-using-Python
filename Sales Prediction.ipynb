# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,KFold
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
dg = pd.read_csv(r"C:\Users\gatla\Downloads\archive (6)\Advertising.csv")

# %%
dg
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
dg.sample(8)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 82           83   75.3   20.3       32.5   11.3
# 111         112  241.7   38.0       23.2   21.8
# 74           75  213.4   24.6       13.1   17.0
# 32           33   97.2    1.5       30.0    9.6
# 144         145   96.2   14.8       38.9   11.4
# 178         179  276.7    2.3       23.7   11.8
# 10           11   66.1    5.8       24.2    8.6
# 124         125  229.5   32.3       74.2   19.7

# %%
dg.sample
# Out:
# <bound method NDFrame.sample of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
dg.shape
# Out:
# (200, 5)

# %%
dg.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
dg.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
dg.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
dg.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
dg
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
dg.shape
# Out:
# (200, 4)

# %%
dg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
dg.size
# Out:
# 800

# %%
dg.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
dg.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
dg.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
dg.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=[5,3])
plt.boxplot(dg,vert=False,data=dg,labels=dg.columns)
plt.show()
# Out:
# C:\Users\gatla\AppData\Local\Temp\ipykernel_5188\266774069.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(dg,vert=False,data=dg,labels=dg.columns)

# %%
sns.histplot(dg['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(dg['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(dg['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(dg['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.distplot(dg['Newspaper'])
# Out:
# C:\Users\gatla\AppData\Local\Temp\ipykernel_5188\3731947690.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dg['Newspaper'])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.distplot(dg['TV'])
# Out:
# C:\Users\gatla\AppData\Local\Temp\ipykernel_5188\1104364246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dg['TV'])
# <Axes: xlabel='TV', ylabel='Density'>

# %%
sns.pairplot(dg)

# %%
sns.heatmap(dg.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=dg.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = dg.iloc[:,-1:]

# %%
xtrain,xtest,ytrain,ytest  = train_test_split(x,y,test_size=0.3,random_state=50)

# %%
print(x.shape)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (200, 3)
# (140, 3)
# (60, 3)

# %%
xtrain,ytrain
# Out:
# (        TV  Radio  Newspaper
#  114   78.2   46.8       34.5
#  187  191.1   28.7       18.2
#  76    27.5    1.6       20.7
#  122  224.0    2.4       15.6
#  142  220.5   33.2       37.9
#  ..     ...    ...        ...
#  132    8.4   27.2        2.1
#  33   265.6   20.0        0.3
#  109  255.4   26.9        5.5
#  139  184.9   43.9        1.7
#  176  248.4   30.2       20.3
#
#  [140 rows x 3 columns],
#       Sales
#  114   14.6
#  187   17.3
#  76     6.9
#  122   11.6
#  142   20.1
#  ..     ...
#  132    5.7
#  33    17.4
#  109   19.8
#  139   20.7
#  176   20.2
#
#  [140 rows x 1 columns])

# %%
xtest,ytest
# Out:
# (        TV  Radio  Newspaper
#  112  175.7   15.4        2.4
#  165  234.5    3.4       84.8
#  12    23.8   35.1       65.9
#  73   129.4    5.7       31.3
#  144   96.2   14.8       38.9
#  20   218.4   27.7       53.4
#  199  232.1    8.6        8.7
#  8      8.6    2.1        1.0
#  39   228.0   37.7       32.0
#  88    88.3   25.5       73.4
#  81   239.8    4.1       36.9
#  197  177.0    9.3        6.4
#  69   216.8   43.9       27.2
#  160  172.5   18.1       30.7
#  25   262.9    3.5       19.5
#  99   135.2   41.7       45.9
#  151  121.0    8.4       48.7
#  23   228.3   16.9       26.2
#  138   43.0   25.9       20.5
#  159  131.7   18.4       34.6
#  89   109.8   47.8       51.4
#  82    75.3   20.3       32.5
#  24    62.3   12.6       18.3
#  174  222.4    3.4       13.1
#  137  273.7   28.9       59.7
#  83    68.4   44.5       35.6
#  107   90.4    0.3       23.2
#  34    95.7    1.4        7.4
#  97   184.9   21.0       22.0
#  167  206.8    5.2       19.4
#  123  123.1   34.6       12.4
#  157  149.8    1.3       24.3
#  75    16.9   43.7       89.4
#  152  197.6   23.3       14.2
#  117   76.4    0.8       14.8
#  149   44.7   25.8       20.6
#  63   102.7   29.6        8.4
#  54   262.7   28.8       15.9
#  125   87.2   11.8       25.9
#  80    76.4   26.7       22.3
#  170   50.0   11.6       18.4
#  183  287.6   43.0       71.8
#  38    43.1   26.7       35.1
#  153  171.3   39.7       37.7
#  40   202.5   22.3       31.6
#  190   39.5   41.1        5.8
#  177  170.2    7.8       35.2
#  131  265.2    2.9       43.0
#  13    97.5    7.6        7.2
#  121   18.8   21.7       50.4
#  1     44.5   39.3       45.1
#  116  139.2   14.3       25.6
#  100  222.4    4.3       49.8
#  166   17.9   37.6       21.6
#  168  215.4   23.6       57.6
#  48   227.2   15.8       49.9
#  178  276.7    2.3       23.7
#  108   13.1    0.4       25.6
#  61   261.3   42.7       54.7
#  16    67.8   36.6      114.0,
#       Sales
#  112   14.1
#  165   11.9
#  12     9.2
#  73    11.0
#  144   11.4
#  20    18.0
#  199   13.4
#  8      4.8
#  39    21.5
#  88    12.9
#  81    12.3
#  197   12.8
#  69    22.3
#  160   14.4
#  25    12.0
#  99    17.2
#  151   11.6
#  23    15.5
#  138    9.6
#  159   12.9
#  89    16.7
#  82    11.3
#  24     9.7
#  174   11.5
#  137   20.8
#  83    13.6
#  107    8.7
#  34     9.5
#  97    15.5
#  167   12.2
#  123   15.2
#  157   10.1
#  75     8.7
#  152   16.6
#  117    9.4
#  149   10.1
#  63    14.0
#  54    20.2
#  125   10.6
#  80    11.8
#  170    8.4
#  183   26.2
#  38    10.1
#  153   19.0
#  40    16.6
#  190   10.8
#  177   11.7
#  131   12.7
#  13     9.7
#  121    7.0
#  1     10.4
#  116   12.2
#  100   11.7
#  166    8.0
#  168   17.1
#  48    14.8
#  178   11.8
#  108    5.3
#  61    24.2
#  16    12.5)

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypredict=model.predict(xtest)
ypredict
# Out:
# array([[13.86471261],
#        [15.0090562 ],
#        [10.60511722],
#        [10.09061905],
#        [10.2058302 ],
#        [18.44112845],
#        [15.35623109],
#        [ 3.50456716],
#        [20.57163267],
#        [11.98288476],
#        [15.08601123],
#        [12.84835102],
#        [21.13029782],
#        [14.37916353],
#        [15.96630443],
#        [16.97004665],
#        [10.28916068],
#        [16.78706185],
#        [ 9.5680503 ],
#        [12.51794578],
#        [16.90028224],
#        [10.16656637],
#        [ 8.06620555],
#        [13.98212973],
#        [21.32738303],
#        [14.23529429],
#        [ 7.20839801],
#        [ 7.55987252],
#        [15.4385442 ],
#        [13.60561012],
#        [14.89945663],
#        [10.22068212],
#        [11.980595  ],
#        [16.40933006],
#        [ 6.58023303],
#        [ 9.63142726],
#        [12.99984158],
#        [20.51038927],
#        [ 9.15336417],
#        [11.31226434],
#        [ 7.30108894],
#        [24.61494601],
#        [ 9.80946097],
#        [18.27320104],
#        [16.57103149],
#        [12.0584219 ],
#        [12.43507395],
#        [16.11514576],
#        [ 8.76566004],
#        [ 7.84595288],
#        [12.21810153],
#        [12.07628047],
#        [14.37606032],
#        [10.49776835],
#        [17.58332133],
#        [16.68505237],
#        [16.43189148],
#        [ 3.56597841],
#        [23.2024176 ],
#        [13.2715782 ]])

# %%
model.score(xtrain,ytrain)*100
# Out:
# 90.28165267955438

# %%
model.score(xtest,ytest)*100
# Out:
# 85.9057555097746

# %%
mean_squared_error(ytest,ypredict)
# Out:
# 2.622772900751398

# %%
mean_absolute_error(ytest,ypredict)
# Out:
# 1.234991924719904

# %%
r2_score(ytest,ypredict)*100
# Out:
# 85.9057555097746

# %%
r = np.sqrt(mean_squared_error(ytest,ypredict))
r
# Out:
# np.float64(1.6194977310115004)

# %%
cv = KFold(n_splits=5,shuffle=True, random_state=0)
cv
# Out:
# KFold(n_splits=5, random_state=0, shuffle=True)

# %%
score=cross_val_score(model,x,y,cv=cv,n_jobs=-1)
finalscore=np.mean(score)
finalscore
# Out:
# np.float64(0.8910650514774895)
